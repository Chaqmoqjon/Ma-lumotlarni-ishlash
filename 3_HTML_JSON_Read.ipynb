# %% [markdown]
# <a href="https://colab.research.google.com/github/Chaqmoqjon/Ma-lumotlarni-ishlash/blob/main/3_HTML_JSON_Read.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# ##HTML

# %%
tashkent = pd.read_html('https://en.wikipedia.org/wiki/Tashkent') #saytning linki orqali jadvallarni import qilish
solar_system = pd.read_html('https://nssdc.gsfc.nasa.gov/planetary/factsheet/')

# %%
len(tashkent), len(solar_system) #nechatdan jadval borligini bilish
# Out:
# (18, 1)

# %%
tashkent[0].head()
# Out:
#                         Tashkent  Тошкент / Toshkent  \
# 0                                       Capital city
# 1                                           Tashkent
# 2  Clockwise from top: Skyline of Tashkent, Kukel...
# 3                                           FlagSeal
# 4                            Nickname: Tosh (A rock)
#
#                       Tashkent  Тошкент / Toshkent.1
# 0                                       Capital city
# 1                                           Tashkent
# 2  Clockwise from top: Skyline of Tashkent, Kukel...
# 3                                           FlagSeal
# 4                            Nickname: Tosh (A rock)

# %%
solar_system[0].head()
# Out:
#                 0        1      2      3      4      5        6       7   \
# 0              NaN  MERCURY  VENUS  EARTH   MOON   MARS  JUPITER  SATURN
# 1    Mass (1024kg)    0.330   4.87   5.97  0.073  0.642     1898     568
# 2    Diameter (km)     4879  12104  12756   3475   6792   142984  120536
# 3  Density (kg/m3)     5429   5243   5514   3340   3934     1326     687
# 4   Gravity (m/s2)      3.7    8.9    9.8    1.6    3.7     23.1     9.0
#
#        8        9       10
# 0  URANUS  NEPTUNE   PLUTO
# 1    86.8      102  0.0130
# 2   51118    49528    2376
# 3    1270     1638    1850
# 4     8.7     11.0     0.7

# %% [markdown]
# ##JSON

# %%
json_data = pd.read_json('/content/universities_ranking.json') #json faylni o'qish
json_data

# %%
import requests

# %%
r = requests.get('https://openlibrary.org/subjects/python.json?published_in=2000-2024') #link orqali json API olish

# %%
r.status_code #200 bo'lsa ishladi degani

# %%
pd.DataFrame(r.json()['works'])
