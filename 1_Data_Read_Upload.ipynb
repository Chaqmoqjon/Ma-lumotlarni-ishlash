# %% [markdown]
# <a href="https://colab.research.google.com/github/Chaqmoqjon/Ma-lumotlarni-ishlash/blob/main/1_Data_Read_Upload.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# !wget https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/refs/heads/main/merc.csv  #link orqali datani olish
# Out:
# --2025-01-21 06:13:28--  https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/refs/heads/main/merc.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 728047 (711K) [text/plain]
# Saving to: ‘merc.csv.1’
#
# merc.csv.1          100%[===================>] 710.98K  --.-KB/s    in 0.06s
#
# 2025-01-21 06:13:29 (12.4 MB/s) - ‘merc.csv.1’ saved [728047/728047]

# %%
# !git clone https://github.com/anvarnarz/praktikum_datasets #Git Hubdan faylni ko'chirib olish
# Out:
# fatal: destination path 'praktikum_datasets' already exists and is not an empty directory.

# %%
df = pd.read_csv('/content/sample_data/california_housing_test.csv') #sample_data
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
merc = pd.read_csv('/content/merc.csv')
# merc = pd.read_csv('/content/praktikum_datasets/merc.csv') #yoki
# merc = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/refs/heads/main/merc.csv') #online berish, (raw)
merc
# Out:
#             model  year  price transmission  mileage fuelType  tax   mpg  \
# 0             SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1         S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 2        SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0
# 3         G Class  2016  61948    Automatic    16000   Petrol  325  30.4
# 4         G Class  2016  73948    Automatic     4000   Petrol  325  30.1
# ...           ...   ...    ...          ...      ...      ...  ...   ...
# 13114     C Class  2020  35999    Automatic      500   Diesel  145  55.4
# 13115     B Class  2020  24699    Automatic     2500   Diesel  145  55.4
# 13116   GLC Class  2019  30999    Automatic    11612   Diesel  145  41.5
# 13117   CLS Class  2019  37990    Automatic     2426   Diesel  145  45.6
# 13118     S Class  2019  54999    Automatic     2075   Diesel  145  52.3
#
#        engineSize
# 0             1.8
# 1             2.1
# 2             5.5
# ...

# %%
df = pd.read_excel('/content/uzbekistan.xlsx', index_col=0, names=['hudud', 'maydon', 'aholi']) #uzb excel fayl
df
# Out:
#                                maydon    aholi
# hudud
# Andijon viloyati                 4200  1899000
# Buxoro viloyati                 39400  1384700
# Fargʻona viloyati                6800  2597000
# Jizzax viloyati                 20500   910500
# Xorazm viloyati                  6300  1200000
# Namangan viloyati                7900  1862000
# Navoiy viloyati                110800   767500
# Qashqadaryo viloyati            28400  2029000
# Qoraqalpogʻiston Respublikasi  160000  1200000
# Samarqand viloyati              16400  2322000
# Sirdaryo viloyati                5100   648100
# Surxondaryo viloyati            20800  1676000
# Toshkent viloyati               15300  4450000

# %%
df.to_csv('newuzb.csv')  #excelni csv ga aylantrish, oxiriga fayl turini yozish shart

# %%
pd.read_csv('/content/newuzb.csv') # faylni o'qish
# Out:
#                             hudud  maydon    aholi
# 0                Andijon viloyati    4200  1899000
# 1                 Buxoro viloyati   39400  1384700
# 2               Fargʻona viloyati    6800  2597000
# 3                 Jizzax viloyati   20500   910500
# 4                 Xorazm viloyati    6300  1200000
# 5               Namangan viloyati    7900  1862000
# 6                 Navoiy viloyati  110800   767500
# 7            Qashqadaryo viloyati   28400  2029000
# 8   Qoraqalpogʻiston Respublikasi  160000  1200000
# 9              Samarqand viloyati   16400  2322000
# 10              Sirdaryo viloyati    5100   648100
# 11           Surxondaryo viloyati   20800  1676000
# 12              Toshkent viloyati   15300  4450000

# %%
obj = df.maydon # ma'lumotning bir qismini olish
obj
# Out:
# hudud
# Andijon viloyati                   4200
# Buxoro viloyati                   39400
# Fargʻona viloyati                  6800
# Jizzax viloyati                   20500
# Xorazm viloyati                    6300
# Namangan viloyati                  7900
# Navoiy viloyati                  110800
# Qashqadaryo viloyati              28400
# Qoraqalpogʻiston Respublikasi    160000
# Samarqand viloyati                16400
# Sirdaryo viloyati                  5100
# Surxondaryo viloyati              20800
# Toshkent viloyati                 15300
# Name: maydon, dtype: int64

# %%
obj.to_excel('uz_maydon.xlsx')  #ma'lumotning bir qismini excelda saqlash, (index = False bo'lsa indekslarni saqlamaydi)

# %%
pd.read_excel('/content/uz_maydon.xlsx', index_col='hudud') # excelni o'qish, (squeeze = True bo'lsa Series typeda saqlaydi. csv fayl uchun ishlaydi)
# Out:
#                                maydon
# hudud
# Andijon viloyati                 4200
# Buxoro viloyati                 39400
# Fargʻona viloyati                6800
# Jizzax viloyati                 20500
# Xorazm viloyati                  6300
# Namangan viloyati                7900
# Navoiy viloyati                110800
# Qashqadaryo viloyati            28400
# Qoraqalpogʻiston Respublikasi  160000
# Samarqand viloyati              16400
# Sirdaryo viloyati                5100
# Surxondaryo viloyati            20800
# Toshkent viloyati               15300

# %%
df = pd.read_excel('/content/praktikum_datasets/uzbekistan.xlsx', index_col=0, names= ['hudud', 'maydon', 'aholi']) #excel fayl uchun
df
# Out:
#                                maydon    aholi
# hudud
# Andijon viloyati                 4200  1899000
# Buxoro viloyati                 39400  1384700
# Fargʻona viloyati                6800  2597000
# Jizzax viloyati                 20500   910500
# Xorazm viloyati                  6300  1200000
# Namangan viloyati                7900  1862000
# Navoiy viloyati                110800   767500
# Qashqadaryo viloyati            28400  2029000
# Qoraqalpogʻiston Respublikasi  160000  1200000
# Samarqand viloyati              16400  2322000
# Sirdaryo viloyati                5100   648100
# Surxondaryo viloyati            20800  1676000
# Toshkent viloyati               15300  4450000

# %%
df2 = pd.read_csv('/content/praktikum_datasets/automobile_data.csv', index_col='index', nrows=10) #csv fayl uchun
df2
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# 5             audi        sedan        99.8   177.3         ohc
# 6             audi        wagon       105.8   192.7         ohc
# 9              bmw        sedan       101.2   176.8         ohc
# 10             bmw        sedan       101.2   176.8         ohc
# 11             bmw        sedan       101.2   176.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage  price
# index
# 0                 four         111               21  13495
# 1                 four         111               21  16500
# 2                  six         154               19  16500
# ...

# %%
df2.to_excel('sample_data/new_cars.xlsx', index=False, columns=['company', 'body-style', 'price']) #indexni o'chirib saqlaydi, xotiradan ortiqcha joy olmaydi, bizga kerakli column lar saqlanadi, faylni istalgan joyga saqlashimiz mumkin
